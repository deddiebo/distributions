# %%
# log normal distribution
# libraries
import numpy as np
import math
from matplotlib import pyplot as plt
from scipy.stats import norm, lognorm

# %%
# just some numbers
x_list = range(1, 20,1)
for x in x_list:
    print('{0:}   {1:.4f}   {2:.4f}'.format(x, np.log(x), np.exp(x)))
    print('                        {:.4f}  {:.4f}'.format(np.exp(np.log(x)), np.log(np.exp(x))))
# Out:
# 1   0.0000   2.7183
#                         1.0000  1.0000
# 2   0.6931   7.3891
#                         2.0000  2.0000
# 3   1.0986   20.0855
#                         3.0000  3.0000
# 4   1.3863   54.5982
#                         4.0000  4.0000
# 5   1.6094   148.4132
#                         5.0000  5.0000
# 6   1.7918   403.4288
#                         6.0000  6.0000
# 7   1.9459   1096.6332
#                         7.0000  7.0000
# 8   2.0794   2980.9580
#                         8.0000  8.0000
# 9   2.1972   8103.0839
#                         9.0000  9.0000
# 10   2.3026   22026.4658
#                         10.0000  10.0000
# 11   2.3979   59874.1417
#                         11.0000  11.0000
# 12   2.4849   162754.7914
#                         12.0000  12.0000
# 13   2.5649   442413.3920
#                         13.0000  13.0000
# 14   2.6391   1202604.2842
#                         14.0000  14.0000
# 15   2.7081   3269017.3725
# ...

# %%
# play with ln and exp
x_list = range(1, 25,1)
ln_list = [np.log(x) for x in x_list]
lnneg_list = [np.log(1/x) for x in x_list]
exp_list = [np.exp(x) for x in x_list]
expneg_list = [np.exp(1/x) for x in x_list]
div_list = [(1/x) for x in x_list]
# difference between values
diff_list = np.diff(ln_list)
# create half points to plot differences
xf_list = [(float(x)  + 0.5) for x in x_list]

fig, axs = plt.subplots(1, 2)
ax11 = axs[0]
ax12 = axs[1]
fig.set_size_inches(12.0, 4.0)

ax11.plot(x_list, ln_list, marker='.', label='ln(x)')
# derivative is 1/x
ax11t = ax11.twinx()  # add a scale for 1/derivative
ax11.scatter(xf_list[:-1], (diff_list), marker='.', color='red', label='approx derivative')
ax11.set_xlabel('x value', fontsize=12)
ax11.set_ylabel('ln(x)', fontsize=12)
ax11.set_title('ln(x) function', fontsize=15)
ax11t.set_ylabel('1/derivative', color='green')
ax11t.scatter(xf_list[:-1], (1/diff_list), marker='.', label='1/derivative', color='green')
ax11t.tick_params(axis='y', labelcolor='green')
ax11t.legend(loc='center right')
ax11t.grid(color='green')
ax11.grid()
ax11.legend()
ax12.plot(x_list, lnneg_list, marker='.')
ax12.set_xlabel('x value', fontsize=12)
ax12.set_ylabel('ln(x)', fontsize=12)
ax12.set_title('ln(1/x) function', fontsize=15)
ax12.grid()
fig.tight_layout()

fig, axs = plt.subplots(1, 2)
ax21 = axs[0]
ax22 = axs[1]
fig.set_size_inches(12.0, 4.0)
ax21.plot(x_list, exp_list, marker='.')
ax21.set_xlabel('x value', fontsize=12)
ax21.set_ylabel('exp(x)', fontsize=12)
ax21.set_title('exp(x) function', fontsize=15)
ax21.grid()
ax22.plot(x_list, div_list, marker='.', label='1/x')
ax22.plot(x_list, expneg_list, marker='.', label='exp(1/x)')
ax22.set_xlabel('x value', fontsize=12)
ax22.set_ylabel('y value', fontsize=12)
ax22.set_title('exp(1/x) function', fontsize=15)
ax22.grid()
ax22.legend()
plt.show();

# %%
# plotting with fig, ax
x_list = range(1, 25,1)
ln_list = [np.log(x) for x in x_list]
exp_list = [np.exp(x) for x in x_list]

#set up figure
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(12.0, 8.0)

# ln function - normal grid
axs[0, 0].plot(x_list, ln_list, marker='.')
axs[0, 0].set_xlabel('x value', fontsize=12)
axs[0, 0].set_ylabel('ln(x)', fontsize=12)
axs[0, 0].set_title('ln(x) function', fontsize=15)
axs[0, 0].grid()

# ln function - x axis log grid
axs[0, 1].plot(x_list, ln_list, marker='.')
axs[0, 1].set_xscale('log')
axs[0, 1].set_xlabel('x value', fontsize=12)
axs[0, 1].set_ylabel('ln(x)', fontsize=12)
axs[0, 1].set_title('ln(x) function  X axis log scale', fontsize=15)
axs[0, 1].grid()

# exp function - normal grid
axs[1, 0].plot(x_list, exp_list, marker='.')
axs[1, 0].set_xlabel('x value', fontsize=12)
axs[1, 0].set_ylabel('exp(x)', fontsize=12)
axs[1, 0].set_title('exp(x) function', fontsize=15)
axs[1, 0].grid()

# exp function - y axis log grid
axs[1, 1].plot(x_list, exp_list, marker='.')
axs[1, 1].set_yscale('log')
axs[1, 1].set_xlabel('x value', fontsize=12)
axs[1, 1].set_ylabel('exp(x)', fontsize=12)
axs[1, 1].set_title('exp(x) function  Y axis log scale', fontsize=15)
axs[1, 1].grid()

plt.tight_layout()

plt.show();

# %%
# log normal function
# product of many independent random variables
mu = 10   # can cause problems if values go below zero
sigma = 1
samples = 10000
number = 20
data_prod = np.ones([samples])
for n in range(number):
    data_prod = data_prod * np.array(np.random.normal(mu, sigma, samples))

fig, axs = plt.subplots(3, 1)
fig.set_size_inches(6.0, 12.0)

#plot histogram of product
axs[0].hist(data_prod, bins=50, label='mu: {:}\nsigma: {:}'.format(mu, sigma))
axs[0].set_title('Multiplied {:} samples * {:} times\nCalculated Distribution'.format(samples, number))
axs[0].set_xlabel('product')
axs[0].set_ylabel('number of occurences')
axs[0].legend(title='original distribution')

# plot histogram of log of product 
ln_data_prod = np.log(data_prod)
axs[1].hist(ln_data_prod, bins=50)
axs[1].set_title('Multiplied {:} samples * {:} times\nln of product'.format(samples, number))
axs[1].set_xlabel('ln(product)')
axs[1].set_ylabel('number of occurences')

# calculate parametric normal fit and plot density histogram
mean_lndp = np.mean(ln_data_prod)
std_lndp = np.sqrt(np.var(ln_data_prod))
dist = norm(mean_lndp, std_lndp)

a2_vals = axs[2].hist(ln_data_prod, bins=50, density=True)
# calculate range of values from histogram
x_values = [value for value in np.linspace(min(a2_vals[1]), max(a2_vals[1]), 50)]
probabilities = [dist.pdf(value) for value in x_values]
axs[2].plot(x_values, probabilities, label='mean: {:.2f}\nsigma: {:.2f}'\
            .format(mean_lndp, math.sqrt(std_lndp)))
axs[2].set_title('Parametric Fit')
axs[2].set_xlabel('ln of product')
axs[2].set_ylabel('relative probability')
axs[2].legend()

plt.tight_layout()
plt.show();

# %%
# reverse it back
rev = np.exp(ln_data_prod)

fig, axs = plt.subplots(1, 2)
fig.set_size_inches(12.0, 4.0)

axs[0].hist(rev, bins=50, label='mu: {:}\nsigma: {:}'.format(mu, sigma))
axs[0].set_title('Back to Original Distribution\ntake exp of ln distribution')
axs[0].set_xlabel('product')
axs[0].set_ylabel('number of occurences')
#plt.xscale('log')
axs[0].legend(title='original distribution')

axs[1].hist(rev, bins=50)
axs[1].set_title('x scale set to log')
axs[1].set_xlabel('product')
axs[1].set_xscale('log')
plt.show();

# %%
# take a normal distribution - ln it and exp it
mu = 10
sigma = .5
samples = 10000
#n_dist = norm(mu, sigma)
#probabilities = [n_dist.pdf(value) for value in values]
values = [value for value in range(int(mu - math.floor(4.*sigma)), int(mu + math.floor(4*sigma)))]
dist = np.random.normal(mu, sigma, samples)

#normal distribution
plt.hist(dist, bins=50, label='mu: {:}\nsigma: {:}'.format(mu, sigma))
plt.title('Normal Distribution  {:} samples'.format(samples))
plt.xlabel('value')
plt.ylabel('number of occurences')
plt.legend(title='original distribution')
plt.show();

#ln of distribution
ln_dist = np.log(dist)
plt.hist(ln_dist, bins=50, label='mu: {:}\nsigma: {:}'.format(mu, sigma))
plt.title('ln of distribution  {:} samples'.format(samples))
plt.xlabel('value')
plt.ylabel('number of occurences')
plt.legend(title='original distribution')
plt.show();

exp_dist = np.exp(dist)
#plt.plot(exp_dist)
plt.hist(exp_dist, bins=50, label='mu: {:}\nsigma: {:}'.format(mu, sigma))
plt.title('exp of distribution  {:} samples'.format(samples))
plt.xlabel('value')
plt.ylabel('number of occurences')
plt.legend(title='original distribution')
#plt.yscale('log')
plt.show();

# %%
# use numpy lognormal to generate distribution
mu = 2
sigma = .5
samples = 10000
ln_dist = np.random.lognormal(mu, sigma, samples)
max_val = max(ln_dist)
hist_vals = plt.hist(ln_dist, bins=50, density=True, label='mu: {:}\nsigma: {:}\
            \nmax value: {:.2f}'.format(mu, sigma, max_val))

# adjust range scale for maximum value in sample
x_values = [x for x in np.linspace(0, math.ceil(max(hist_vals[1])), 50)]

# pdf function from scipy
probabilities = [lognorm.pdf(value, sigma, 0, np.exp(mu)) for value in x_values]
plt.plot(x_values, probabilities, label='s: {:.2f}\nscale: {:.2f}'\
            .format(sigma, np.exp(mu)))
plt.title('lognormal distribution  {:} samples'.format(samples))
plt.xlabel('value')
plt.ylabel('relative probability')

plt.legend()
plt.show();

# %%
# log normal distribution - examples
#         mu, sigma
params1 = [0.0, 0.5]
params2 = [0.5, 0.5]
params3 = [1.0, 0.5]
#params4 = [0.0, 0.25]
#params5 = [0.0, 1]
params_list = [params1, params2, params3]
#params_list = [params1, params2, params3, params4, params5]

delta_x = 0.1
x_values = np.arange(0.0, 8.0, delta_x)

for n in range(len(params_list)):
    p_list = []
    p_mu = params_list[n][0]
    p_sigma = params_list[n][1]
    m, v = lognorm.stats(p_sigma, 0, np.exp(p_mu), moments='mv')
    print('mu: {:} sigma: {:} mean: {:.2f} variance: {:.2f}'.format(p_mu, p_sigma, m, v))
    for x in x_values:     
        p = lognorm.pdf(x, p_sigma, 0, np.exp(p_mu))
        p_list.append(p)
    plt.plot(x_values, p_list, label='mu: {0:.2f}\nsigma: {1:.2f}'.format(p_mu, p_sigma))
    
plt.title('lognormal distribution', fontsize=15)
plt.legend(title = 'parameters', loc = 'upper right')
plt.ylabel('relative probability', fontsize=12)
plt.xlabel('value', fontsize=12)
plt.grid()
plt.show();
# Out:
# mu: 0.0 sigma: 0.5 mean: 1.13 variance: 0.36
# mu: 0.5 sigma: 0.5 mean: 1.87 variance: 0.99
# mu: 1.0 sigma: 0.5 mean: 3.08 variance: 2.69

# %%
# CDF for lognormal distribution

for n in range(len(params_list)):
    p_list = []
    for x in x_values:
        p = lognorm.cdf(x, params_list[n][1], 0, np.exp(params_list[n][0]))
        p_list.append(p)
    plt.plot(x_values, p_list, label='mu: {0:.2f}\nsigma: {1:.2f}'.format(params_list[n][0], params_list[n][1]))

plt.title('lognormal cumulative probability', fontsize=15)
plt.legend(title = 'parameters', loc = 'lower right')
plt.ylabel('probability', fontsize=12)
plt.xlabel('value', fontsize=12)
plt.grid()
plt.show();

# PPF functionfor n in range(len(lambda_list)):
for n in range(len(params_list)):
    p_list = []
    for x in x_values:
        p = lognorm.ppf(x, params_list[n][1], 0, np.exp(params_list[n][0]))
        p_list.append(p)
    plt.plot(x_values, p_list, label='mu: {0:.2f}\nsigma: {1:.2f}'.format(params_list[n][0], params_list[n][1]))
    
plt.title('Probability Percent Function', fontsize=15)
plt.legend(title = 'parameters', loc = 'upper left')
plt.xlabel('cumulative probability', fontsize=12)
plt.ylabel('value', fontsize=12)
plt.grid()
plt.show();
